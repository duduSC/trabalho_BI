# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
movies_csv= "movies.csv"

movie_df= pd.read_csv(movies_csv,sep="|")

movie_df
# Out:
# C:\Users\duduc\AppData\Local\Temp\ipykernel_9328\4218373251.py:6: DtypeWarning: Columns (0: anoLancamento) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df= pd.read_csv(movies_csv,sep="|")
#                 id       tituloPincipal       tituloOriginal anoLancamento  \
# 0        tt0000009           Miss Jerry           Miss Jerry          1894
# 1        tt0000009           Miss Jerry           Miss Jerry          1894
# 2        tt0000009           Miss Jerry           Miss Jerry          1894
# 3        tt0000502             Bohemios             Bohemios          1905
# 4        tt0000502             Bohemios             Bohemios          1905
# ...            ...                  ...                  ...           ...
# 1045156  tt9916538  Kuambil Lagi Hatiku  Kuambil Lagi Hatiku          2019
# 1045157  tt9916730               6 Gunn               6 Gunn          2017
# ...

# %%
movie_df = movie_df.drop_duplicates(['id'])
movie_df = movie_df[~movie_df.isin([r"\N"])]
movie_df= movie_df.dropna()
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
movie_df = movie_df.drop(columns=["personagem","nomeArtista","anoNascimento","anoFalecimento","profissao","titulosMaisConhecidos","generoArtista"])
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
movie_df["genero"] = movie_df["genero"].str.split(",")
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
dim_filme = movie_df[["id","tituloPincipal","tituloOriginal"]]
dim_filme = dim_filme.rename(columns={"id":"id_imdb","tituloPincipal":"titulo_principal","tituloOriginal":"titulo_original"})
dim_filme
# Out:
#            id_imdb                      titulo_principal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                  titulo_original
# 0                                     Miss Jerry
# 20                The Fairylogue and Radio-Plays
# 87                             The Life of Moses
# 124                               De fire djævle
# ...

# %%
fato_filme = movie_df[["id","anoLancamento","tempoMinutos","notaMedia","numeroVotos"]]
fato_filme = fato_filme.rename(columns={"id":"id_imdb","anoLancamento":"ano_lancamento","tempoMinutos":"tempo_minutos","notaMedia":"nota_media","numeroVotos":"numero_votos"})
fato_filme
# Out:
#            id_imdb ano_lancamento tempo_minutos  nota_media  numero_votos
# 0        tt0000009           1894            45         5.3           200
# 20       tt0000679           1908           120         5.2            66
# 87       tt0001285           1909            50         5.5            58
# 124      tt0001614           1911            60         6.3            31
# 136      tt0001790           1913            60         6.2            49
# ...            ...            ...           ...         ...           ...
# 1042277  tt9739386           1989            88         4.4            14
# 1043522  tt9815554           2021            84         6.0         10071
# 1043801  tt9832110           1962            85         6.5            25
# 1043996  tt9844738           1986            93         6.4             6
# 1044609  tt9883996           2020           113         6.9          5557
#
# [51324 rows x 5 columns]

# %%
dim_genero= movie_df["genero"]
dim_genero = dim_genero.explode("genero")
dim_genero = dim_genero.rename("nome")
dim_genero = dim_genero.drop_duplicates()
dim_genero
# Out:
# 0            Romance
# 1          Adventure
# 2            Fantasy
# 3          Biography
# 4              Drama
# 5             Family
# 11           History
# 24               War
# 28            Action
# 30          Thriller
# 41             Crime
# 58           Mystery
# 61           Western
# 68            Horror
# 71            Comedy
# 94             Music
# 172           Sci-Fi
# 923            Sport
# 1772     Documentary
# 2674         Musical
# 3871       Film-Noir
# 5448       Animation
# 11594           News
# 55370          Adult
# 79755          Short
# Name: nome, dtype: str

# %%
df_explode = movie_df[["id","genero"]]
df_explode = df_explode.explode("genero")
df_explode= df_explode.rename(columns={"id":"id_imdb"})

dim_filme["id_imdb"]= dim_filme.id_imdb.astype("str")
df_explode["id_imdb"] = df_explode.id_imdb.astype("str")


bridge_temp = pd.merge(df_explode,dim_filme,on="id_imdb", how="inner")

bridge_temp
# Out:
#          id_imdb     genero                titulo_principal  \
# 0      tt0000009    Romance                      Miss Jerry
# 1      tt0000679  Adventure  The Fairylogue and Radio-Plays
# 2      tt0000679    Fantasy  The Fairylogue and Radio-Plays
# 3      tt0001285  Biography               The Life of Moses
# 4      tt0001285      Drama               The Life of Moses
# ...          ...        ...                             ...
# 95326  tt9832110      Drama                     Mooncussers
# 95327  tt9844738     Comedy               Kocamin Nisanlisi
# 95328  tt9883996  Biography                     Dream Horse
# 95329  tt9883996     Comedy                     Dream Horse
# 95330  tt9883996      Drama                     Dream Horse
#
#                       titulo_original
# 0                          Miss Jerry
# 1      The Fairylogue and Radio-Plays
# 2      The Fairylogue and Radio-Plays
# 3                   The Life of Moses
# 4                   The Life of Moses
# ...

# %%
bridge_filmeGenero = bridge_temp[["id_imdb","genero"]]
bridge_filmeGenero = bridge_filmeGenero.drop_duplicates()
bridge_filmeGenero
# Out:
#          id_imdb     genero
# 0      tt0000009    Romance
# 1      tt0000679  Adventure
# 2      tt0000679    Fantasy
# 3      tt0001285  Biography
# 4      tt0001285      Drama
# ...          ...        ...
# 95326  tt9832110      Drama
# 95327  tt9844738     Comedy
# 95328  tt9883996  Biography
# 95329  tt9883996     Comedy
# 95330  tt9883996      Drama
#
# [95331 rows x 2 columns]

# %%
load_dotenv()
DB_SENHA=os.getenv("DB_SENHA")
db = create_engine('postgresql://postgres:{DB_SENHA}@localhost:5432/DataWarehouse_Filmes')

# %%
query = "SELECT * FROM fato_filme"
consulta = pd.read_sql(query,db)
consulta
# Out:
# Empty DataFrame
# Columns: [sk_filme, sk_data_lancamento, nota_media, numero_votos, tempo_minutos]
# Index: []

# %%
dim_genero.to_sql(
    name="dim_genero",
    con=db,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# File c:\Users\duduc\trabalho_BI\.venv\Lib\site-packages\sqlalchemy\engine\base.py:2125, in Connection._exec_insertmany_context(self, dialect, context)
#    2124     else:
# -> 2125         dialect.do_execute(
#    2126             cursor,
#    2127             sub_stmt,
#    2128             sub_params,
#    2129             context,
#    2130         )
#    2132 except BaseException as e:
#
# File c:\Users\duduc\trabalho_BI\.venv\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# UniqueViolation: ERRO:  duplicar valor da chave viola a restrição de unicidade "dim_genero_nome_key"
# DETAIL:  Chave (nome)=(Romance) já existe.
# ...

# %%
pd.read_sql("SELECT * FROM dim_genero",db)
# Out:
#     sk_genero         nome
# 0           1      Romance
# 1           2    Adventure
# 2           3      Fantasy
# 3           4    Biography
# 4           5        Drama
# 5           6       Family
# 6           7      History
# 7           8          War
# 8           9       Action
# 9          10     Thriller
# 10         11        Crime
# 11         12      Mystery
# 12         13      Western
# 13         14       Horror
# 14         15       Comedy
# 15         16        Music
# 16         17       Sci-Fi
# 17         18        Sport
# 18         19  Documentary
# 19         20      Musical
# 20         21    Film-Noir
# 21         22    Animation
# 22         23         News
# 23         24        Adult
# 24         25        Short

# %%
dim_filme.to_sql(
    name="dim_filme",
    con=db,
    if_exists="append",
    index=False)
# Out:
# 324

# %%
pd.read_sql("SELECT * FROM dim_filme",db)
# Out:
#        sk_filme    id_imdb                      titulo_principal  \
# 0             1  tt0000009                            Miss Jerry
# 1             2  tt0000679        The Fairylogue and Radio-Plays
# 2             3  tt0001285                     The Life of Moses
# 3             4  tt0001614                       The Four Devils
# 4             5  tt0001790  Les Misérables, Part 1: Jean Valjean
# ...         ...        ...                                   ...
# 51319     51320  tt9739386                          Kinali Hanzo
# 51320     51321  tt9815554                         Not to Forget
# 51321     51322  tt9832110                           Mooncussers
# 51322     51323  tt9844738                     Kocamin Nisanlisi
# 51323     51324  tt9883996                           Dream Horse
#
#                                titulo_original
# 0                                   Miss Jerry
# 1               The Fairylogue and Radio-Plays
# ...
