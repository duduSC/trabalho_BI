# %%
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv
movies_csv= "movies.csv"

movie_df= pd.read_csv(movies_csv,sep="|")

movie_df
# Out:
# C:\Users\duduc\AppData\Local\Temp\ipykernel_12580\3720649117.py:7: DtypeWarning: Columns (0: anoLancamento) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie_df= pd.read_csv(movies_csv,sep="|")
#                 id       tituloPincipal       tituloOriginal anoLancamento  \
# 0        tt0000009           Miss Jerry           Miss Jerry          1894
# 1        tt0000009           Miss Jerry           Miss Jerry          1894
# 2        tt0000009           Miss Jerry           Miss Jerry          1894
# 3        tt0000502             Bohemios             Bohemios          1905
# 4        tt0000502             Bohemios             Bohemios          1905
# ...            ...                  ...                  ...           ...
# 1045156  tt9916538  Kuambil Lagi Hatiku  Kuambil Lagi Hatiku          2019
# 1045157  tt9916730               6 Gunn               6 Gunn          2017
# ...

# %%
movie_df = movie_df.drop_duplicates(['id'])
movie_df = movie_df[~movie_df.isin([r"\N"])]
movie_df= movie_df.dropna()
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
movie_df = movie_df.drop(columns=["personagem","nomeArtista","anoNascimento","anoFalecimento","profissao","titulosMaisConhecidos","generoArtista"])
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
movie_df["genero"] = movie_df["genero"].str.split(",")
movie_df
# Out:
#                 id                        tituloPincipal  \
# 0        tt0000009                            Miss Jerry
# 20       tt0000679        The Fairylogue and Radio-Plays
# 87       tt0001285                     The Life of Moses
# 124      tt0001614                       The Four Devils
# 136      tt0001790  Les Misérables, Part 1: Jean Valjean
# ...            ...                                   ...
# 1042277  tt9739386                          Kinali Hanzo
# 1043522  tt9815554                         Not to Forget
# 1043801  tt9832110                           Mooncussers
# 1043996  tt9844738                     Kocamin Nisanlisi
# 1044609  tt9883996                           Dream Horse
#
#                                   tituloOriginal anoLancamento tempoMinutos  \
# 0                                     Miss Jerry          1894           45
# 20                The Fairylogue and Radio-Plays          1908          120
# ...

# %%
movie_df = movie_df.rename(columns={"id":"id_imdb","tituloPincipal":"titulo_principal","tituloOriginal":"titulo_original","notaMedia":"nota_media","numeroVotos":"numero_votos","tempoMinutos":"tempo_minutos"})
movie_df = movie_df[movie_df["numero_votos"] > 1000]
movie_df
# Out:
#            id_imdb                           titulo_principal  \
# 187      tt0002130                            Dante's Inferno
# 328      tt0002844  Fantômas: In the Shadow of the Guillotine
# 373      tt0003014                              Ingeborg Holm
# 390      tt0003037                 Fantomas: The Man in Black
# 412      tt0003165          Fantômas: The Dead Man Who Killed
# ...            ...                                        ...
# 1034633  tt9260636                                      Bigil
# 1039522  tt9577852                      Rolling Thunder Revue
# 1041644  tt9695258                 So My Grandma's a Lesbian!
# 1043522  tt9815554                              Not to Forget
# 1044609  tt9883996                                Dream Horse
#
#                                            titulo_original anoLancamento  \
# 187                                              L'Inferno          1911
# ...

# %%
dim_filme = movie_df[["id_imdb","titulo_principal","titulo_original"]]
dim_filme
# Out:
#            id_imdb                           titulo_principal  \
# 187      tt0002130                            Dante's Inferno
# 328      tt0002844  Fantômas: In the Shadow of the Guillotine
# 373      tt0003014                              Ingeborg Holm
# 390      tt0003037                 Fantomas: The Man in Black
# 412      tt0003165          Fantômas: The Dead Man Who Killed
# ...            ...                                        ...
# 1034633  tt9260636                                      Bigil
# 1039522  tt9577852                      Rolling Thunder Revue
# 1041644  tt9695258                 So My Grandma's a Lesbian!
# 1043522  tt9815554                              Not to Forget
# 1044609  tt9883996                                Dream Horse
#
#                                            titulo_original
# 187                                              L'Inferno
# 328                  Fantômas - À l'ombre de la guillotine
# ...

# %%
dim_genero= movie_df["genero"]
dim_genero = dim_genero.explode("genero")
dim_genero = dim_genero.rename("nome")
dim_genero = dim_genero.drop_duplicates()
dim_genero = pd.DataFrame(dim_genero)
dim_genero["id"]= range(len(dim_genero))
dim_genero
# Out:
#               nome  id
# 0        Adventure   0
# 1            Drama   1
# 2          Fantasy   2
# 3            Crime   3
# 10         Mystery   4
# 13          Horror   5
# 19         History   6
# 28          Action   7
# 31          Comedy   8
# 33             War   9
# 36         Romance  10
# 37       Biography  11
# 45          Sci-Fi  12
# 52          Family  13
# 80        Thriller  14
# 87         Western  15
# 159          Sport  16
# 169    Documentary  17
# 282        Musical  18
# 368          Music  19
# 402      Film-Noir  20
# 573      Animation  21
# 11147        Adult  22
# 17418         News  23

# %%
df_explode = movie_df[["id_imdb","genero"]]
df_explode = df_explode.explode("genero")
df_explode= df_explode.rename(columns={"id":"id_imdb","genero":"nome"})

dim_filme["id_imdb"]= dim_filme.id_imdb.astype("str")
df_explode["id_imdb"] = df_explode.id_imdb.astype("str")
df_bridge = df_explode.merge(dim_genero,on="nome",how="inner")
df_bridge= df_bridge.rename(columns={"id":"id_genero"})

df_bridge
# Out:
#          id_imdb       nome  id_genero
# 0      tt0002130  Adventure          0
# 1      tt0002130      Drama          1
# 2      tt0002130    Fantasy          2
# 3      tt0002844      Crime          3
# 4      tt0002844      Drama          1
# ...          ...        ...        ...
# 17903  tt9695258     Comedy          8
# 17904  tt9815554      Drama          1
# 17905  tt9883996  Biography         11
# 17906  tt9883996     Comedy          8
# 17907  tt9883996      Drama          1
#
# [17908 rows x 3 columns]

# %%
load_dotenv()
DB_SENHA=os.getenv("DB_SENHA")
db = create_engine('postgresql://eduar:{DB_SENHA}@localhost:5432/DW_Filmes')

# %%
dim_genero = dim_genero[["nome"]]

# %%
dim_genero.to_sql("dim_genero",
                  con=db,
                  if_exists="delete_rows",
                  index=False)
dim_filme.to_sql("dim_filme",
                  con=db,
                  if_exists="delete_rows",
                  index=False)
# Out:
# 566

# %%
pd.read_sql("select * from dim_filme limit 10",db)
# Out:
#    sk_filme    id_imdb                                   titulo_principal  \
# 0    256621  tt0002130                                    Dante's Inferno
# 1    256622  tt0002844          Fantômas: In the Shadow of the Guillotine
# 2    256623  tt0003014                                      Ingeborg Holm
# 3    256624  tt0003037                         Fantomas: The Man in Black
# 4    256625  tt0003165                  Fantômas: The Dead Man Who Killed
# 5    256626  tt0003419                              The Student of Prague
# 6    256627  tt0003643  The Avenging Conscience: or 'Thou Shalt Not Kill'
# 7    256628  tt0003740                                            Cabiria
# 8    256629  tt0003772                                         Cinderella
# 9    256630  tt0003930              Fantomas: The Mysterious Finger Print
#
#                                      titulo_original
# 0                                          L'Inferno
# ...

# %%
pd.read_sql("SELECT * FROM dim_genero limit 10",db)
# Out:
#    sk_genero       nome
# 0        126  Adventure
# 1        127      Drama
# 2        128    Fantasy
# 3        129      Crime
# 4        130    Mystery
# 5        131     Horror
# 6        132    History
# 7        133     Action
# 8        134     Comedy
# 9        135        War

# %%
df_bridge.to_sql("bridge_filme_genero",
                 con=db,
                 if_exists="replace",
                 index=False)

pd.read_sql("select * from bridge_filme_genero limit 10",db)
# Out:
#      id_imdb       nome  id_genero
# 0  tt0002130  Adventure          0
# 1  tt0002130      Drama          1
# 2  tt0002130    Fantasy          2
# 3  tt0002844      Crime          3
# 4  tt0002844      Drama          1
# 5  tt0003014      Drama          1
# 6  tt0003037      Crime          3
# 7  tt0003037      Drama          1
# 8  tt0003165      Crime          3
# 9  tt0003165      Drama          1

# %%
query = "SELECT dim_genero.sk_genero, dim_filme.sk_filme FROM bridge_filme_genero INNER JOIN dim_filme ON bridge_filme_genero.id_imdb = dim_filme.id_imdb INNER JOIN dim_genero ON bridge_filme_genero.nome = dim_genero.nome"
df_bridge = pd.read_sql(query,db)
df_bridge.to_sql("bridge_filme_genero",
                 con=db,
                 if_exists="replace",
                 index=False)
pd.read_sql("select * from bridge_filme_genero limit 10",db)
# Out:
#    sk_genero  sk_filme
# 0        126    256621
# 1        127    256621
# 2        128    256621
# 3        129    256622
# 4        127    256622
# 5        127    256623
# 6        129    256624
# 7        127    256624
# 8        129    256625
# 9        127    256625

# %%
movie_df.to_sql("tabela_aux",
                con=db,
                if_exists="replace",
                index=False)
# Out:
# 566
